# %% [markdown]
# <a href="https://colab.research.google.com/github/MahanandAdimulam/Credit-card-fraud-detection-using-Autoencoders/blob/master/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import important libraries

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# #Load the data

# %%
df = pd.read_csv("/content/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# #Exploring the dataset

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# 31 columns, 2 of which are Time and Amount. The rest are output from the PCA transformation.

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# No null values in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# We have an highly imbalanced dataset. Normal transactions overwhelm the fradulent ones bya humangous margin. Lets look at the two type of transactions.

# %%
frauds = df[df['Class'] == 1]
normal = df[df['Class'] == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
pd.value_counts(df['Class'], sort = True).plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# #Prepare the data

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %% [markdown]
# #Build the model

# %% [markdown]
# Our Autoencoder uses 4 fully connected layers with 14, 7, 7 and 29 neurons respectively. The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh",
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# #Train the model

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally, the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 54s 7ms/step - loss: 0.7990 - accuracy: 0.5864 - val_loss: 0.7795 - val_accuracy: 0.6368
# Epoch 2/100
#   62/7108 [..............................] - ETA: 17s - loss: 0.7579 - accuracy: 0.6129
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.7396 - accuracy: 0.6415 - val_loss: 0.7651 - val_accuracy: 0.6432
# Epoch 3/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7288 - accuracy: 0.6512 - val_loss: 0.7553 - val_accuracy: 0.6613
# Epoch 4/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.7222 - accuracy: 0.6603 - val_loss: 0.7508 - val_accuracy: 0.6630
# Epoch 5/100
# 7108/7108 [==============================] - 25s 3ms/step - loss: 0.7176 - accuracy: 0.6656 - val_loss: 0.7485 - val_accuracy: 0.6716
# Epoch 6/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7134 - accuracy: 0.6755 - val_loss: 0.7461 - val_accuracy: 0.6795
# Epoch 7/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7109 - accuracy: 0.6810 - val_loss: 0.7442 - val_accuracy: 0.6868
# Epoch 8/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.7091 - accuracy: 0.6849 - val_loss: 0.7429 - val_accuracy: 0.6836
# Epoch 9/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7078 - accuracy: 0.6890 - val_loss: 0.7411 - val_accuracy: 0.6870
# Epoch 10/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7063 - accuracy: 0.6931 - val_loss: 0.7403 - val_accuracy: 0.6975
# Epoch 11/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7038 - accuracy: 0.6997 - val_loss: 0.7368 - val_accuracy: 0.7123
# Epoch 12/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7009 - accuracy: 0.7163 - val_loss: 0.7342 - val_accuracy: 0.7162
# Epoch 13/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.6985 - accuracy: 0.7209 - val_loss: 0.7315 - val_accuracy: 0.7191
# Epoch 14/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6955 - accuracy: 0.7230 - val_loss: 0.7288 - val_accuracy: 0.7240
# Epoch 15/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6946 - accuracy: 0.7250 - val_loss: 0.7292 - val_accuracy: 0.7215
# Epoch 16/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6938 - accuracy: 0.7268 - val_loss: 0.7289 - val_accuracy: 0.7295
# Epoch 17/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6930 - accuracy: 0.7278 - val_loss: 0.7272 - val_accuracy: 0.7274
# Epoch 18/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6924 - accuracy: 0.7288 - val_loss: 0.7287 - val_accuracy: 0.7286
# Epoch 19/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6919 - accuracy: 0.7305 - val_loss: 0.7270 - val_accuracy: 0.7295
# Epoch 20/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6924 - accuracy: 0.7313 - val_loss: 0.7274 - val_accuracy: 0.7315
# Epoch 21/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.6913 - accuracy: 0.7332 - val_loss: 0.7254 - val_accuracy: 0.7370
# Epoch 22/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.6907 - accuracy: 0.7342 - val_loss: 0.7276 - val_accuracy: 0.7275
# Epoch 23/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6905 - accuracy: 0.7341 - val_loss: 0.7281 - val_accuracy: 0.7332
# Epoch 24/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6904 - accuracy: 0.7350 - val_loss: 0.7252 - val_accuracy: 0.7353
# Epoch 25/100
# 7108/7108 [==============================] - 25s 3ms/step - loss: 0.6903 - accuracy: 0.7350 - val_loss: 0.7273 - val_accuracy: 0.7331
# Epoch 26/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6899 - accuracy: 0.7365 - val_loss: 0.7285 - val_accuracy: 0.7292
# Epoch 27/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6895 - accuracy: 0.7360 - val_loss: 0.7294 - val_accuracy: 0.7314
# Epoch 28/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6896 - accuracy: 0.7370 - val_loss: 0.7292 - val_accuracy: 0.7265
# Epoch 29/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6894 - accuracy: 0.7368 - val_loss: 0.7252 - val_accuracy: 0.7364
# Epoch 30/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.6889 - accuracy: 0.7379 - val_loss: 0.7262 - val_accuracy: 0.7340
# Epoch 31/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6891 - accuracy: 0.7370 - val_loss: 0.7265 - val_accuracy: 0.7226
# Epoch 32/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6890 - accuracy: 0.7377 - val_loss: 0.7273 - val_accuracy: 0.7414
# Epoch 33/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6887 - accuracy: 0.7392 - val_loss: 0.7250 - val_accuracy: 0.7310
# Epoch 34/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6889 - accuracy: 0.7380 - val_loss: 0.7246 - val_accuracy: 0.7417
# Epoch 35/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6886 - accuracy: 0.7385 - val_loss: 0.7257 - val_accuracy: 0.7328
# Epoch 36/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6891 - accuracy: 0.7382 - val_loss: 0.7254 - val_accuracy: 0.7399
# Epoch 37/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6885 - accuracy: 0.7386 - val_loss: 0.7249 - val_accuracy: 0.7436
# Epoch 38/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6885 - accuracy: 0.7388 - val_loss: 0.7261 - val_accuracy: 0.7414
# Epoch 39/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6885 - accuracy: 0.7393 - val_loss: 0.7247 - val_accuracy: 0.7381
# Epoch 40/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6887 - accuracy: 0.7391 - val_loss: 0.7238 - val_accuracy: 0.7441
# Epoch 41/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6883 - accuracy: 0.7395 - val_loss: 0.7257 - val_accuracy: 0.7385
# Epoch 42/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6883 - accuracy: 0.7392 - val_loss: 0.7250 - val_accuracy: 0.7373
# Epoch 43/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6885 - accuracy: 0.7397 - val_loss: 0.7250 - val_accuracy: 0.7461
# Epoch 44/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6884 - accuracy: 0.7395 - val_loss: 0.7257 - val_accuracy: 0.7433
# Epoch 45/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6883 - accuracy: 0.7394 - val_loss: 0.7255 - val_accuracy: 0.7326
# Epoch 46/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6881 - accuracy: 0.7398 - val_loss: 0.7256 - val_accuracy: 0.7385
# Epoch 47/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6882 - accuracy: 0.7395 - val_loss: 0.7248 - val_accuracy: 0.7428
# Epoch 48/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6879 - accuracy: 0.7391 - val_loss: 0.7258 - val_accuracy: 0.7405
# Epoch 49/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6881 - accuracy: 0.7390 - val_loss: 0.7248 - val_accuracy: 0.7468
# Epoch 50/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6878 - accuracy: 0.7401 - val_loss: 0.7253 - val_accuracy: 0.7411
# Epoch 51/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6879 - accuracy: 0.7399 - val_loss: 0.7256 - val_accuracy: 0.7431
# Epoch 52/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6880 - accuracy: 0.7398 - val_loss: 0.7242 - val_accuracy: 0.7461
# Epoch 53/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6880 - accuracy: 0.7388 - val_loss: 0.7264 - val_accuracy: 0.7425
# Epoch 54/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6880 - accuracy: 0.7395 - val_loss: 0.7242 - val_accuracy: 0.7444
# Epoch 55/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6881 - accuracy: 0.7400 - val_loss: 0.7240 - val_accuracy: 0.7465
# Epoch 56/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6877 - accuracy: 0.7404 - val_loss: 0.7235 - val_accuracy: 0.7452
# Epoch 57/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6879 - accuracy: 0.7394 - val_loss: 0.7250 - val_accuracy: 0.7429
# Epoch 58/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6879 - accuracy: 0.7401 - val_loss: 0.7237 - val_accuracy: 0.7421
# Epoch 59/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6879 - accuracy: 0.7398 - val_loss: 0.7241 - val_accuracy: 0.7416
# Epoch 60/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6878 - accuracy: 0.7399 - val_loss: 0.7254 - val_accuracy: 0.7326
# Epoch 61/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6876 - accuracy: 0.7405 - val_loss: 0.7293 - val_accuracy: 0.7307
# Epoch 62/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6878 - accuracy: 0.7397 - val_loss: 0.7266 - val_accuracy: 0.7357
# Epoch 63/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6877 - accuracy: 0.7399 - val_loss: 0.7234 - val_accuracy: 0.7377
# Epoch 64/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6877 - accuracy: 0.7396 - val_loss: 0.7285 - val_accuracy: 0.7412
# Epoch 65/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6875 - accuracy: 0.7395 - val_loss: 0.7242 - val_accuracy: 0.7420
# Epoch 66/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6875 - accuracy: 0.7409 - val_loss: 0.7240 - val_accuracy: 0.7409
# Epoch 67/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.6878 - accuracy: 0.7393 - val_loss: 0.7245 - val_accuracy: 0.7404
# Epoch 68/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6877 - accuracy: 0.7395 - val_loss: 0.7241 - val_accuracy: 0.7409
# Epoch 69/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6876 - accuracy: 0.7396 - val_loss: 0.7248 - val_accuracy: 0.7381
# Epoch 70/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6876 - accuracy: 0.7405 - val_loss: 0.7267 - val_accuracy: 0.7303
# Epoch 71/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6875 - accuracy: 0.7408 - val_loss: 0.7261 - val_accuracy: 0.7375
# Epoch 72/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6878 - accuracy: 0.7401 - val_loss: 0.7233 - val_accuracy: 0.7435
# Epoch 73/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6876 - accuracy: 0.7407 - val_loss: 0.7249 - val_accuracy: 0.7480
# Epoch 74/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6877 - accuracy: 0.7404 - val_loss: 0.7244 - val_accuracy: 0.7422
# Epoch 75/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6877 - accuracy: 0.7401 - val_loss: 0.7239 - val_accuracy: 0.7383
# Epoch 76/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6874 - accuracy: 0.7406 - val_loss: 0.7240 - val_accuracy: 0.7421
# Epoch 77/100
# 7108/7108 [==============================] - 26s 4ms/step - loss: 0.6876 - accuracy: 0.7408 - val_loss: 0.7246 - val_accuracy: 0.7392
# Epoch 78/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6878 - accuracy: 0.7389 - val_loss: 0.7236 - val_accuracy: 0.7434
# Epoch 79/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6875 - accuracy: 0.7400 - val_loss: 0.7241 - val_accuracy: 0.7431
# Epoch 80/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6872 - accuracy: 0.7413 - val_loss: 0.7258 - val_accuracy: 0.7273
# Epoch 81/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6875 - accuracy: 0.7403 - val_loss: 0.7257 - val_accuracy: 0.7437
# Epoch 82/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6878 - accuracy: 0.7403 - val_loss: 0.7238 - val_accuracy: 0.7439
# Epoch 83/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6872 - accuracy: 0.7406 - val_loss: 0.7242 - val_accuracy: 0.7389
# Epoch 84/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6875 - accuracy: 0.7398 - val_loss: 0.7257 - val_accuracy: 0.7460
# Epoch 85/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6872 - accuracy: 0.7413 - val_loss: 0.7254 - val_accuracy: 0.7370
# Epoch 86/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6874 - accuracy: 0.7403 - val_loss: 0.7240 - val_accuracy: 0.7386
# Epoch 87/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6876 - accuracy: 0.7402 - val_loss: 0.7244 - val_accuracy: 0.7374
# Epoch 88/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6873 - accuracy: 0.7399 - val_loss: 0.7238 - val_accuracy: 0.7458
# Epoch 89/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6873 - accuracy: 0.7401 - val_loss: 0.7248 - val_accuracy: 0.7358
# Epoch 90/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6875 - accuracy: 0.7396 - val_loss: 0.7232 - val_accuracy: 0.7387
# Epoch 91/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6873 - accuracy: 0.7400 - val_loss: 0.7244 - val_accuracy: 0.7340
# Epoch 92/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.6873 - accuracy: 0.7404 - val_loss: 0.7265 - val_accuracy: 0.7292
# Epoch 93/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6874 - accuracy: 0.7402 - val_loss: 0.7242 - val_accuracy: 0.7483
# Epoch 94/100
# 7108/7108 [==============================] - 25s 3ms/step - loss: 0.6876 - accuracy: 0.7407 - val_loss: 0.7237 - val_accuracy: 0.7405
# Epoch 95/100
# 7108/7108 [==============================] - 24s 3ms/step - loss: 0.6872 - accuracy: 0.7405 - val_loss: 0.7277 - val_accuracy: 0.7311
# Epoch 96/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6872 - accuracy: 0.7399 - val_loss: 0.7244 - val_accuracy: 0.7440
# Epoch 97/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6873 - accuracy: 0.7404 - val_loss: 0.7253 - val_accuracy: 0.7323
# Epoch 98/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.6871 - accuracy: 0.7396 - val_loss: 0.7243 - val_accuracy: 0.7374
# Epoch 99/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.6873 - accuracy: 0.7399 - val_loss: 0.7240 - val_accuracy: 0.7474
# Epoch 100/100
# 7108/7108 [==============================] - 25s 4ms/step - loss: 0.6874 - accuracy: 0.7407 - val_loss: 0.7246 - val_accuracy: 0.7437

# %%
autoencoder.save('CreditCardFraudDetectionModel.h5')

# %% [markdown]
# #Evaluate the model

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
# Out:
# 1781/1781 [==============================] - 3s 2ms/step

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.723802      0.001720
# std                3.507844      0.041443
# min                0.035945      0.000000
# 25%                0.228737      0.000000
# 50%                0.382677      0.000000
# 75%                0.614504      0.000000
# max              293.482350      1.000000

# %% [markdown]
# #Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# #Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %% [markdown]
# ROC curves are very useful tool for understanding the performance of binary classifiers. However, our case is a bit out of the ordinary. We have a very imbalanced dataset. Nonetheless, let's have a look at our ROC curve:

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# The ROC curve plots the true positive rate versus the false positive rate, over different threshold values. Basically, we want the blue line to be as close as possible to the upper left corner. While our results look pretty good, we have to keep in mind of the nature of our dataset. ROC doesn't look very useful for us.

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# You can see that as the reconstruction error increases our precision rises as well. Let's have a look at the recall:

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Here, we have the exact opposite situation. As the reconstruction error increases the recall decreases.

# %% [markdown]
# #Prediction

# %% [markdown]
# Our model is a bit different this time. It doesn't know how to predict new values. But we don't need that. In order to predict whether or not a new/unseen transaction is normal or fraudulent, we'll calculate the reconstruction error from the transaction data itself. If the error is larger than a predefined threshold, we'll mark it as a fraud (since our model should have a low error on normal transactions). Let's pick that value:

# %%
threshold = 2.9

# %% [markdown]
# And see how well we're dividing the two types of transactions:

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# I know, that chart might be a bit deceiving. Let's have a look at the confusion matrix:

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# Our model seems to catch a lot of the fraudulent cases. Of course, there is a catch (see what I did there?). The number of normal transactions classified as frauds is really high. Is this really a problem? Probably it is. You might want to increase or decrease the value of the threshold, depending on the problem. That one is up to you.

# %% [markdown]
# #Conclusion

# %% [markdown]
# We've created a very simple Deep Autoencoder in Keras that can reconstruct what non fraudulent transactions looks like. Initially, I was a bit skeptical about whether or not this whole thing is gonna work out, bit it kinda did. Think about it, we gave a lot of one-class examples (normal transactions) to a model and it learned (somewhat) how to discriminate whether or not new examples belong to that same class. Isn't that cool? Our dataset was kind of magical, though. We really don't know what the original features look like.
